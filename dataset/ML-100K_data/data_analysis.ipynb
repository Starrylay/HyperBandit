# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #绘图工具
import seaborn as sns
import warnings
import time
import torch
warnings.filterwarnings("ignore")
#设置jupyter显示多行结果
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all' #默认为'last'
# #显示所有列
pd.set_option('display.max_columns', None) #原来中间会有部分列的显示被省略
# #显示所有行
# pd.set_option('display.max_rows', None)
#设置value的显示长度为100，默认为50
pd.set_option('max_colwidth',100)
plt.rcParams['font.sans-serif'] = ['SimHei']  #显示中文
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %%
online_learning_8 = np.loadtxt("./online_learning_8.txt")
online_learning_2 = np.loadtxt("./online_learning_2.txt")
batch_test_8 = np.loadtxt("./batch_test_8.txt")
batch_test_2 = np.loadtxt("./batch_test_2.txt")

# %%
item_1 = set(online_learning_8[:,1])
len(item_1)
item_2 = set(online_learning_2[:,1])
len(item_2)
item_3 = set(batch_test_8[:,1])
len(item_3)
item_4 = set(batch_test_2[:,1])
len(item_4)
print("----------data 1 to data 1--------------")
len(item_1 & item_2)
len(item_2 - item_1)
print("----------data 1 to data 2--------------")
len(item_1 & item_4)
len(item_4 - item_1)
print("----------data 2 to data 2--------------")
len(item_3 & item_4)
len(item_4 - item_3)
# Out:
# 1438
# 1177
# 1583
# 1268
# ----------data 1 to data 1--------------
# 1149
# 28
# ----------data 1 to data 2--------------
# 1157
# 111
# ----------data 2 to data 2--------------
# 1230
# 38
