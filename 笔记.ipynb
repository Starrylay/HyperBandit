# %% [markdown]
# ### linucb
# + Mlinucb：一共M个用户类，从0更新每个用户类的参数
# + user feature是更新的
# + item feature是固定的
#
# ### colinucb
# + M个用户类，从0更新每个用户类的参数
# + 有一个固定的用户类关系矩阵W
# + 决策的时候根据W的影响得出user feature（Cotheta）
#
# ### FactorUCB
# + M个用户
#
# ###
