# %%
import time
import pickle
# #写一个函数，返回当前时间
def get_time():
    return time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
start = time.time()
#
# print(start)
# print(time.localtime())
# end = time.time()
# print(end-start)
# print(str(get_time()))

# 写一个简便的返回当前时间字符串的函数
def get_time_str():
    return time.strftime("%Y-%m-%d_%H-%M-%S", time.localtime())
a =1

with open("{}.pkl".format(get_time()), "wb") as f:
    pickle.dump(a, f)

    print("done")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_56520\1116439578.py in <module>
#      17 a =1
#      18
# ---> 19 with open("{}.pkl".format(get_time()), "wb") as f:
#      20     pickle.dump(a, f)
#      21
#
# OSError: [Errno 22] Invalid argument: '2023-04-04 19:21:53.pkl'

# %%
print("hello world")
print(time.time())
# Out:
# hello world
# 1680606933.1588986

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a random matrix
matrix = np.random.rand(5, 5)

# Plot the matrix
plt.imshow(matrix, cmap='gray', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
import pickle 
filename = r"./result_log/resultdata_NYC_2023-04-17_23-41-11.pkl"
# filename = "model_log\model_trained21.0.pkl"
with open(filename, 'rb') as file:
    algresult  = pickle.load(file)
for alg_name, reward in algresult.AlgReward.items():
    
    reward = algresult.AlgRewardRatio_vsRandom[alg_name]

    print(alg_name, reward[-1])
# Out:
# LinUCB_ItemBased 9.685582601181046
# HyperBandit w/o Hyper 0 9.647990782082672
# HyperBandit w/o Hyper 1 5.046521676508714
# HyperBandit w/o Hyper 2 4.253060636612416
# HyperBandit w/o Hyper 3 3.823419271208411
# HyperBandit w/o Hyper 4 3.144462048106006
# HyperBandit w/o Hyper 5 2.9039320178597148
# HyperBandit w/o Hyper 6 3.315569638484805
# HyperBandit w/o Hyper 7 3.037879879014835
# HyperBandit w/o Hyper 8 3.1889673051994816
# HyperBandit w/o Hyper 9 2.9449805559556386
# HyperBandit w/o Hyper 10 2.8539536223534494
# HyperBandit w/o Hyper 11 2.885640213164338
# HyperBandit w/o Hyper 12 2.815497623505689
# HyperBandit w/o Hyper 13 2.701857986461184
# HyperBandit w/o Hyper 14 2.6550482500360073
# HyperBandit w/o Hyper 15 2.601325075615728
# HyperBandit w/o Hyper 16 2.7128042632867637
# HyperBandit w/o Hyper 17 2.8483364539824283
# HyperBandit w/o Hyper 18 2.7934610398962985
# HyperBandit w/o Hyper 19 3.1247299438283163
# HyperBandit w/o Hyper 20 3.0735993086562003
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_37684/2178039591.py in <module>
#       3 filename = "model_log\model_trained21.0.pkl"
#       4 with open(filename, 'rb') as file:
# ----> 5     algresult  = pkl.load(filename)
#       6 for alg_name, reward in algresult.AlgReward.items():
#       7     print(alg_name,reward)
#
# TypeError: file must have 'read' and 'readline' attributes
